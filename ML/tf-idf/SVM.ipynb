# %%
import os

os.chdir('/Users/shreygupta/Documents/Classes/CS598DLH/')
os.getcwd()
# Out:
# '/Users/shreygupta/Documents/Classes/CS598DLH'

# %%
from feature_generation import FeatureGeneration
from sklearn.model_selection import KFold
from sklearn.feature_selection import SelectKBest, mutual_info_classif
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.metrics import f1_score
import pandas as pd
import csv
import numpy as np
import collections
from sklearn import svm
import weka.core.jvm as jvm
from weka.core.converters import Loader
from weka.filters import Filter
from weka.attribute_selection import ASEvaluation, AttributeSelection
from weka.classifiers import Classifier, Evaluation
from imblearn.over_sampling import SMOTE

# jvm.start()

# %%
class SVM:
    def __init__(self, x_train, y_train, x_test, y_test, k):
        self.svm = svm.SVC(kernel='linear')
        self.x_train = x_train
        self.y_train = y_train
        self.x_test = x_test
        self.y_test = y_test
        self.k = k
        print(self.x_train.shape, self.y_train.shape, self.x_test.shape, self.y_test.shape)

    def feature_selection_SelectKBest(self):
        k_best = SelectKBest(mutual_info_classif, k=self.k)
        k_best.fit(self.x_train, self.y_train)
        self.x_train = k_best.transform(self.x_train)
        self.x_test = k_best.transform(self.x_test)
        
    def feature_selection_ExtraTreesClassifier(self):
        clf = ExtraTreesClassifier(n_estimators=100, random_state=42)
        clf.fit(self.x_train, self.y_train)
        importances = clf.feature_importances_
        indices = np.argsort(importances)[::-1]
        self.x_train = self.x_train[:, indices[:self.k]]
        self.x_test = self.x_test[:, indices[:self.k]]
    
    def feature_selection_InfoGainAttributeEval(self, morbidity):
        loader = Loader(classname="weka.core.converters.ArffLoader")
        train_data = loader.load_file(f"./dataset/train/train_{morbidity}_tfidf.arff")
        train_data.class_is_last()

        # Initialize attribute selection
        eval = ASEvaluation(classname="weka.attributeSelection.InfoGainAttributeEval")
        search = AttributeSelection()
        search.evaluator = eval
        search.select_attributes(train_data)
        selected_attributes = search.selected_attributes
        filtered_attributes = np.delete(selected_attributes, [-1])

        # Apply selected attributes to the training and testing sets
        self.x_train = self.x_train[:, filtered_attributes]
        self.x_test = self.x_test[:, filtered_attributes]
        
    def train(self):
        self.svm.fit(self.x_train, self.y_train)

    def test_and_evaluate(self):
        y_pred = self.svm.predict(self.x_test)
        f1_macro = f1_score(self.y_test, y_pred, average='macro')
        f1_micro = f1_score(self.y_test, y_pred, average='micro')
        print(f"Macro F1 score: {f1_macro} and Micro F1 Score {f1_micro}")
        return f1_macro, f1_micro

# %%
morbidities = ['Asthma', 'CAD', 'CHF', 'Depression', 'Diabetes', 'Gallstones', 'GERD', 'Gout', 'Hypercholesterolemia', 'Hypertension', 'Hypertriglyceridemia', 'OA', 'Obesity', 'OSA', 'PVD', 'Venous_Insufficiency']
column_headings = ["Morbidity Class", "SVM_Macro F1", "SVM_Micro F1"]

# %%
with open("./results/tf-idf/performance_SVM_AllFeatures.csv", "w", newline="") as file:
    writer = csv.writer(file)

    # write the RF heading and the subheadings for Micro F1 and Macro F1
    writer.writerow(column_headings)
    
all_f1_macro_scores = []
all_f1_micro_scores = []

for morbidity in morbidities:
    train_preprocessed_df = pd.read_csv('./dataset/train/train_intuitive_preprocessed.csv')
    train_preprocessed_df = train_preprocessed_df[train_preprocessed_df[morbidity].isin([1.0, 0.0])]

    X, Y, words = FeatureGeneration(train_preprocessed_df, morbidity).tf_idf()
    if len(collections.Counter(list(Y)).keys()) < 2:
        f1_macro = 1
        f1_micro = 1
    else:
        print(morbidity)
        smote = SMOTE(random_state=42,k_neighbors=2)
        X_train_resampled, y_train_resampled = smote.fit_resample(X, Y)
        X, Y =  X_train_resampled, y_train_resampled
        
        # add KFold cross validation
        skf = KFold(n_splits=10, shuffle=True, random_state=42)

        f1_macro_list = []
        f1_micro_list = []
        for train_idx, val_idx in skf.split(X, Y):
            X_train_fold, Y_train_fold = X[train_idx], Y[train_idx]
            X_val_fold, Y_val_fold = X[val_idx], Y[val_idx]

            # Training RF using TF-IDF Representation
            svm_obj = SVM(X_train_fold, Y_train_fold, X_val_fold, Y_val_fold, 0)
            svm_obj.train()

            f1_macro, f1_micro = svm_obj.test_and_evaluate()

            f1_macro_list.append(f1_macro)
            f1_micro_list.append(f1_micro)

        f1_macro = np.mean(f1_macro_list)
        f1_micro = np.mean(f1_micro_list)
    print(f"Macro F1 score: {f1_macro} and Micro F1 Score {f1_micro}")
    all_f1_macro_scores.append(f1_macro)
    all_f1_micro_scores.append(f1_micro)

    row_heading = morbidity

    # data to be written to the CSV file
    data = [f1_macro, f1_micro]

    with open("./results/tf-idf/performance_SVM_AllFeatures.csv", "a", newline="") as file:
        writer = csv.writer(file)
        row = [row_heading]
        row.extend(data)
        writer.writerow(row)

with open("./results/tf-idf/performance_SVM_AllFeatures.csv", "a", newline="") as file:
    writer = csv.writer(file)
    row = ["Overall-Average"]
    row.extend([sum(all_f1_macro_scores)/len(all_f1_macro_scores),  sum(all_f1_micro_scores)/len(all_f1_micro_scores) ])
    writer.writerow(row)
# Out:
# Asthma
# (903, 600) (903,) (101, 600) (101,)
# Macro F1 score: 0.9306658821221928 and Micro F1 Score 0.9306930693069307
# (903, 600) (903,) (101, 600) (101,)
# Macro F1 score: 0.9405882352941177 and Micro F1 Score 0.9405940594059405
# (903, 600) (903,) (101, 600) (101,)
# Macro F1 score: 0.9501824997533788 and Micro F1 Score 0.9504950495049505
# (903, 600) (903,) (101, 600) (101,)
# Macro F1 score: 0.9306658821221928 and Micro F1 Score 0.9306930693069307
# (904, 600) (904,) (100, 600) (100,)
# Macro F1 score: 0.92 and Micro F1 Score 0.92
# (904, 600) (904,) (100, 600) (100,)
# Macro F1 score: 0.96999699969997 and Micro F1 Score 0.97
# (904, 600) (904,) (100, 600) (100,)
# Macro F1 score: 0.9495916927109587 and Micro F1 Score 0.9500000000000001
# (904, 600) (904,) (100, 600) (100,)
# Macro F1 score: 0.968324358568261 and Micro F1 Score 0.97
# (904, 600) (904,) (100, 600) (100,)
# Macro F1 score: 0.9393939393939393 and Micro F1 Score 0.94
# (904, 600) (904,) (100, 600) (100,)
# Macro F1 score: 0.9594155844155845 and Micro F1 Score 0.96
# Macro F1 score: 0.9458825074080595 and Micro F1 Score 0.9462475247524751
# CAD
# (585, 600) (585,) (65, 600) (65,)
# Macro F1 score: 0.8918983131385128 and Micro F1 Score 0.8923076923076924
# (585, 600) (585,) (65, 600) (65,)
# Macro F1 score: 0.8732943469785575 and Micro F1 Score 0.8769230769230769
# (585, 600) (585,) (65, 600) (65,)
# Macro F1 score: 0.7998104714522627 and Micro F1 Score 0.8000000000000002
# (585, 600) (585,) (65, 600) (65,)
# Macro F1 score: 0.8117760617760617 and Micro F1 Score 0.8153846153846154
# (585, 600) (585,) (65, 600) (65,)
# Macro F1 score: 0.8099415204678362 and Micro F1 Score 0.8153846153846154
# (585, 600) (585,) (65, 600) (65,)
# Macro F1 score: 0.9380952380952381 and Micro F1 Score 0.9384615384615385
# (585, 600) (585,) (65, 600) (65,)
# Macro F1 score: 0.
# (868, 600) (868,) (96, 600) (96,)
# Macro F1 score: 0.7603906673901248 and Micro F1 Score 0.7604166666666666
# Macro F1 score: 0.7872799155832734 and Micro F1 Score 0.7894115120274914

# %%
with open("./results/tf-idf/performance_SVM_ExtraTreesClassifier.csv", "w", newline="") as file:
    writer = csv.writer(file)

    # write the RF heading and the subheadings for Micro F1 and Macro F1
    writer.writerow(column_headings)
    
all_f1_macro_scores = []
all_f1_micro_scores = []

for morbidity in morbidities:
    train_preprocessed_df = pd.read_csv('./dataset/train/train_intuitive_preprocessed.csv')
    train_preprocessed_df = train_preprocessed_df[train_preprocessed_df[morbidity].isin([1.0, 0.0])]

    X, Y, words = FeatureGeneration(train_preprocessed_df, morbidity).tf_idf()
    if len(collections.Counter(list(Y)).keys()) < 2:
        f1_macro = 1
        f1_micro = 1
    else:
        print(morbidity)
        smote = SMOTE(random_state=42,k_neighbors=2)
        X_train_resampled, y_train_resampled = smote.fit_resample(X, Y)
        X, Y =  X_train_resampled, y_train_resampled
        
        # add KFold cross validation
        skf = KFold(n_splits=10, shuffle=True, random_state=42)

        f1_macro_list = []
        f1_micro_list = []
        for train_idx, val_idx in skf.split(X, Y):
            X_train_fold, Y_train_fold = X[train_idx], Y[train_idx]
            X_val_fold, Y_val_fold = X[val_idx], Y[val_idx]

            # Training RF using TF-IDF Representation
            svm_obj = SVM(X_train_fold, Y_train_fold, X_val_fold, Y_val_fold, 100)
            svm_obj.feature_selection_ExtraTreesClassifier()
            svm_obj.train()

            f1_macro, f1_micro = svm_obj.test_and_evaluate()

            f1_macro_list.append(f1_macro)
            f1_micro_list.append(f1_micro)

        f1_macro = np.mean(f1_macro_list)
        f1_micro = np.mean(f1_micro_list)
    print(f"Macro F1 score: {f1_macro} and Micro F1 Score {f1_micro}")
    all_f1_macro_scores.append(f1_macro)
    all_f1_micro_scores.append(f1_micro)

    row_heading = morbidity

    # data to be written to the CSV file
    data = [f1_macro, f1_micro]

    with open("./results/tf-idf/performance_SVM_ExtraTreesClassifier.csv", "a", newline="") as file:
        writer = csv.writer(file)
        row = [row_heading]
        row.extend(data)
        writer.writerow(row)

with open("./results/tf-idf/performance_SVM_ExtraTreesClassifier.csv", "a", newline="") as file:
    writer = csv.writer(file)
    row = ["Overall-Average"]
    row.extend([sum(all_f1_macro_scores)/len(all_f1_macro_scores),  sum(all_f1_micro_scores)/len(all_f1_micro_scores) ])
    writer.writerow(row)
# Out:
# Asthma
# (903, 600) (903,) (101, 600) (101,)
# Macro F1 score: 0.8910463861920173 and Micro F1 Score 0.8910891089108911
# (903, 600) (903,) (101, 600) (101,)
# Macro F1 score: 0.9009803921568629 and Micro F1 Score 0.9009900990099011
# (903, 600) (903,) (101, 600) (101,)
# Macro F1 score: 0.9007468553459118 and Micro F1 Score 0.9009900990099011
# (903, 600) (903,) (101, 600) (101,)
# Macro F1 score: 0.8904014994574331 and Micro F1 Score 0.8910891089108911
# (904, 600) (904,) (100, 600) (100,)
# Macro F1 score: 0.9097744360902256 and Micro F1 Score 0.91
# (904, 600) (904,) (100, 600) (100,)
# Macro F1 score: 0.9299929992999301 and Micro F1 Score 0.93
# (904, 600) (904,) (100, 600) (100,)
# Macro F1 score: 0.8696741854636592 and Micro F1 Score 0.87
# (904, 600) (904,) (100, 600) (100,)
# Macro F1 score: 0.8858802780371406 and Micro F1 Score 0.89
# (904, 600) (904,) (100, 600) (100,)
# Macro F1 score: 0.8181818181818181 and Micro F1 Score 0.82
# (904, 600) (904,) (100, 600) (100,)
# Macro F1 score: 0.898000815993472 and Micro F1 Score 0.9
# Macro F1 score: 0.889467966621847 and Micro F1 Score 0.8904158415841585
# CAD
# (585, 600) (585,) (65, 600) (65,)
# Macro F1 score: 0.8461174242424242 and Micro F1 Score 0.8461538461538461
# (585, 600) (585,) (65, 600) (65,)
# Macro F1 score: 0.8732943469785575 and Micro F1 Score 0.8769230769230769
# (585, 600) (585,) (65, 600) (65,)
# Macro F1 score: 0.8614072494669509 and Micro F1 Score 0.8615384615384615
# (585, 600) (585,) (65, 600) (65,)
# Macro F1 score: 0.8443486590038315 and Micro F1 Score 0.8461538461538461
# (585, 600) (585,) (65, 600) (65,)
# Macro F1 score: 0.8132183908045977 and Micro F1 Score 0.8153846153846154
# (585, 600) (585,) (65, 600) (65,)
# Macro F1 score: 0.9380952380952381 and Micro F1 Score 0.9384615384615385
# (585, 600) (585,) (65, 600) (65,)
# Macro F1 score: 0.7537878787878789 and Micro F1 Score 0.7538461538461538
# (585, 600) (585,) (65, 600) (65,)
# Macro F1 score: 0.6575670498084292 and Micro F1 Score 0.6615384615384615
# (585, 600) (585,) (65, 600) (65,)
# Macro F1 score: 0.8076923076923077 and Micro F1 Score 0.8153846153846154
# (585, 600) (585,) (65, 600) (65,)
# Macro F1 score: 0.8918983131385128 and Micro F1 Score 0.8923076923076924
# Macro F1 score: 0.8287426858018728 and Micro F1 Score 0.8307692307692307
# Macro F1 score: 1 and Micro F1 Score 1
# Depression
# (828, 600) (828,) (92, 600) (92,)
# Macro F1 score: 0.7274558596990166 and Micro F1 Score 0.7282608695652174
# (828, 600) (828,) (92, 600) (92,)
# Macro F1 score: 0.6520094562647754 and Micro F1 Score 0.6521739130434783
# (828, 600) (828,) (92, 600) (92,)
# Macro F1 score: 0.6956521739130435 and Micro F1 Score 0.6956521739130435
# (828, 600) (828,) (92, 600) (92,)
# Macro F1 score: 0.6480153036824485 and Micro F1 Score 0.6521739130434783
# (828, 600) (828,) (92, 600) (92,)
# Macro F1 score: 0.6802109552918614 and Micro F1 Score 0.6847826086956522
# (828, 600) (828,) (92, 600) (92,)
# Macro F1 score: 0.6661828737300435 and Micro F1 Score 0.6739130434782609
# (828, 600) (828,) (92, 600) (92,)
# Macro F1 score: 0.8673076923076923 and Micro F1 Score 0.8695652173913043
# (828, 600) (828,) (92, 600) (92,)
# Macro F1 score: 0.7061425061425062 and Micro F1 Score 0.717391304347826
# (828, 600) (828,) (92, 600) (92,)
# Macro F1 score: 0.7608695652173914 and Micro F1 Score 0.7608695652173914
# (828, 600) (828,) (92, 600) (92,)
# Macro F1 score: 0.7809523809523811 and Micro F1 Score 0.782608695652174
# Macro F1 score: 0.7184798767201159 and Micro F1 Score 0.7217391304347827
# Diabetes
# (712, 600) (712,) (80, 600) (80,)
# Macro F1 score: 0.7103357472021066 and Micro F1 Score 0.7250000000000001
# (712, 600) (712,) (80, 600) (80,)
# Macro F1 score: 0.7797570850202429 and Micro F1 Score 0.7875
# (713, 600) (713,) (79, 600) (79,)
# Macro F1 score: 0.7948051948051948 and Micro F1 Score 0.7974683544303798
# (713, 600) (713,) (79, 600) (79,)
# Macro F1 score: 0.805642119074955 and Micro F1 Score 0.810126582278481
# (713, 600) (713,) (79, 600) (79,)
# Macro F1 score: 0.8353375020041687 and Micro F1 Score 0.8354430379746836
# (713, 600) (713,) (79, 600) (79,)
# Macro F1 score: 0.7458172458172458 and Micro F1 Score 0.7468354430379747
# (713, 600) (713,) (79, 600) (79,)
# Macro F1 score: 0.7510504201680672 and Micro F1 Score 0.7721518987341772
# (713, 600) (713,) (79, 600) (79,)
# Macro F1 score: 0.7825805407155577 and Micro F1 Score 0.7848101265822784
# (713, 600) (713,) (79, 600) (79,)
# Macro F1 score: 0.886002886002886 and Micro F1 Score 0.8860759493670886
# (713, 600) (713,) (79, 600) (79,)
# Macro F1 score: 0.8985879332477535 and Micro F1 Score 0.8987341772151899
# Macro F1 score: 0.7989916674058178 and Micro F1 Score 0.8044145569620254
# Gallstones
# (910, 600) (910,) (102, 600) (102,)
# Macro F1 score: 0.664841182913472 and Micro F1 Score 0.6764705882352942
# (910, 600) (910,) (102, 600) (102,)
# Macro F1 score: 0.744212962962963 and Micro F1 Score 0.7450980392156863
# (911, 600) (911,) (101, 600) (101,)
# Macro F1 score: 0.603921568627451 and Micro F1 Score 0.6039603960396039
# (911, 600) (911,) (101, 600) (101,)
# Macro F1 score: 0.5167464114832536 and Micro F1 Score 0.5247524752475248
# (911, 600) (911,) (101, 600) (101,)
# Macro F1 score: 0.693069306930693 and Micro F1 Score 0.693069306930693
# (911, 600) (911,) (101, 600) (101,)
# Macro F1 score: 0.653329410610964 and Micro F1 Score 0.6534653465346535
# (911, 600) (911,) (101, 600) (101,)
# Macro F1 score: 0.6900306900306901 and Micro F1 Score 0.693069306930693
# (911, 600) (911,) (101, 600) (101,)
# Macro F1 score: 0.6593253968253967 and Micro F1 Score 0.6633663366336634
# (911, 600) (911,) (101, 600) (101,)
# Macro F1 score: 0.6994047619047619 and Micro F1 Score 0.7029702970297029
# (911, 600) (911,) (101, 600) (101,)
# Macro F1 score: 0.6823899371069182 and Micro F1 Score 0.6831683168316832
# Macro F1 score: 0.6607271629396564 and Micro F1 Score 0.6639390409629198
# GERD
# (669, 600) (669,) (75, 600) (75,)
# Macro F1 score: 0.650286944045911 and Micro F1 Score 0.6533333333333333
# (669, 600) (669,) (75, 600) (75,)
# Macro F1 score: 0.6527777777777779 and Micro F1 Score 0.6533333333333333
# (669, 600) (669,) (75, 600) (75,)
# Macro F1 score: 0.6088832943715159 and Micro F1 Score 0.6133333333333333
# (669, 600) (669,) (75, 600) (75,)
# Macro F1 score: 0.5248868778280542 and Micro F1 Score 0.5333333333333333
# (670, 600) (670,) (74, 600) (74,)
# Macro F1 score: 0.5898004434589801 and Micro F1 Score 0.5945945945945946
# (670, 600) (670,) (74, 600) (74,)
# Macro F1 score: 0.6747252747252748 and Micro F1 Score 0.6756756756756757
# (670, 600) (670,) (74, 600) (74,)
# Macro F1 score: 0.4861111111111111 and Micro F1 Score 0.4864864864864865
# (670, 600) (670,) (74, 600) (74,)
# Macro F1 score: 0.6216216216216217 and Micro F1 Score 0.6216216216216216
# (670, 600) (670,) (74, 600) (74,)
# Macro F1 score: 0.6696428571428572 and Micro F1 Score 0.6756756756756757
# (670, 600) (670,) (74, 600) (74,)
# Macro F1 score: 0.5577405051089261 and Micro F1 Score 0.581081081081081
# Macro F1 score: 0.603647670719203 and Micro F1 Score 0.6088468468468468
# Gout
# (932, 600) (932,) (104, 600) (104,)
# Macro F1 score: 0.7578015836050304 and Micro F1 Score 0.7596153846153846
# (932, 600) (932,) (104, 600) (104,)
# Macro F1 score: 0.768888888888889 and Micro F1 Score 0.7692307692307693
# (932, 600) (932,) (104, 600) (104,)
# Macro F1 score: 0.7911047345767576 and Micro F1 Score 0.7980769230769231
# (932, 600) (932,) (104, 600) (104,)
# Macro F1 score: 0.749165120593692 and Micro F1 Score 0.75
# (932, 600) (932,) (104, 600) (104,)
# Macro F1 score: 0.7788257050392973 and Micro F1 Score 0.7788461538461539
# (932, 600) (932,) (104, 600) (104,)
# Macro F1 score: 0.7884615384615384 and Micro F1 Score 0.7884615384615384
# (933, 600) (933,) (103, 600) (103,)
# Macro F1 score: 0.7180213348437647 and Micro F1 Score 0.7184466019417476
# (933, 600) (933,) (103, 600) (103,)
# Macro F1 score: 0.6794908062234795 and Micro F1 Score 0.6796116504854369
# (933, 600) (933,) (103, 600) (103,)
# Macro F1 score: 0.7632183908045977 and Micro F1 Score 0.7669902912621359
# (933, 600) (933,) (103, 600) (103,)
# Macro F1 score: 0.775343764817449 and Micro F1 Score 0.7766990291262136
# Macro F1 score: 0.7570321867854495 and Micro F1 Score 0.7585978342046303
# Hypercholesterolemia
# (471, 600) (471,) (53, 600) (53,)
# Macro F1 score: 0.6927536231884057 and Micro F1 Score 0.6981132075471698
# (471, 600) (471,) (53, 600) (53,)
# Macro F1 score: 0.8096264367816093 and Micro F1 Score 0.8113207547169812
# (471, 600) (471,) (53, 600) (53,)
# Macro F1 score: 0.7153598281417829 and Micro F1 Score 0.7169811320754716
# (471, 600) (471,) (53, 600) (53,)
# Macro F1 score: 0.6774078052273542 and Micro F1 Score 0.6792452830188679
# (472, 600) (472,) (52, 600) (52,)
# Macro F1 score: 0.7062146892655368 and Micro F1 Score 0.7115384615384616
# (472, 600) (472,) (52, 600) (52,)
# Macro F1 score: 0.845925925925926 and Micro F1 Score 0.8461538461538461
# (472, 600) (472,) (52, 600) (52,)
# Macro F1 score: 0.6533333333333332 and Micro F1 Score 0.6538461538461539
# (472, 600) (472,) (52, 600) (52,)
# Macro F1 score: 0.6700261291526688 and Micro F1 Score 0.6730769230769231
# (472, 600) (472,) (52, 600) (52,)
# Macro F1 score: 0.6923076923076923 and Micro F1 Score 0.7115384615384616
# (472, 600) (472,) (52, 600) (52,)
# Macro F1 score: 0.6729559748427674 and Micro F1 Score 0.6730769230769231
# Macro F1 score: 0.7135911438167076 and Micro F1 Score 0.7174891146589261
# Hypertension
# (770, 600) (770,) (86, 600) (86,)
# Macro F1 score: 0.7650611071171818 and Micro F1 Score 0.7790697674418605
# (770, 600) (770,) (86, 600) (86,)
# Macro F1 score: 0.7153888582460011 and Micro F1 Score 0.7209302325581395
# (770, 600) (770,) (86, 600) (86,)
# Macro F1 score: 0.6975108225108224 and Micro F1 Score 0.6976744186046512
# (770, 600) (770,) (86, 600) (86,)
# Macro F1 score: 0.660541717707908 and Micro F1 Score 0.6627906976744186
# (770, 600) (770,) (86, 600) (86,)
# Macro F1 score: 0.6839526337280523 and Micro F1 Score 0.686046511627907
# (770, 600) (770,) (86, 600) (86,)
# Macro F1 score: 0.7440476190476191 and Micro F1 Score 0.7441860465116278
# (771, 600) (771,) (85, 600) (85,)
# Macro F1 score: 0.7590702947845804 and Micro F1 Score 0.7647058823529412
# (771, 600) (771,) (85, 600) (85,)
# Macro F1 score: 0.7044095145360969 and Micro F1 Score 0.7058823529411765
# (771, 600) (771,) (85, 600) (85,)
# Macro F1 score: 0.7032537355118 and Micro F1 Score 0.7058823529411765
# (771, 600) (771,) (85, 600) (85,)
# Macro F1 score: 0.717607973421927 and Micro F1 Score 0.7176470588235294
# Macro F1 score: 0.715084427661199 and Micro F1 Score 0.7184815321477428
# Hypertriglyceridemia
# (997, 600) (997,) (111, 600) (111,)
# Macro F1 score: 0.801398828887443 and Micro F1 Score 0.8018018018018018
# (997, 600) (997,) (111, 600) (111,)
# Macro F1 score: 0.8194534808067664 and Micro F1 Score 0.8198198198198198
# (997, 600) (997,) (111, 600) (111,)
# Macro F1 score: 0.8013988288874431 and Micro F1 Score 0.8018018018018018
# (997, 600) (997,) (111, 600) (111,)
# Macro F1 score: 0.8098229583095373 and Micro F1 Score 0.8108108108108109
# (997, 600) (997,) (111, 600) (111,)
# Macro F1 score: 0.9188925874807178 and Micro F1 Score 0.918918918918919
# (997, 600) (997,) (111, 600) (111,)
# Macro F1 score: 0.9006105006105005 and Micro F1 Score 0.9009009009009009
# (997, 600) (997,) (111, 600) (111,)
# Macro F1 score: 0.8287732402370707 and Micro F1 Score 0.8288288288288288
# (997, 600) (997,) (111, 600) (111,)
# Macro F1 score: 0.8619975134687111 and Micro F1 Score 0.8648648648648649
# (998, 600) (998,) (110, 600) (110,)
# Macro F1 score: 0.8281846581048247 and Micro F1 Score 0.8363636363636363
# (998, 600) (998,) (110, 600) (110,)
# Macro F1 score: 0.8090751301760477 and Micro F1 Score 0.8090909090909091
# Macro F1 score: 0.8379607726969063 and Micro F1 Score 0.8393202293202293
# OA
# (840, 600) (840,) (94, 600) (94,)
# Macro F1 score: 0.7649999999999999 and Micro F1 Score 0.7659574468085105
# (840, 600) (840,) (94, 600) (94,)
# Macro F1 score: 0.7753499487879822 and Micro F1 Score 0.776595744680851
# (840, 600) (840,) (94, 600) (94,)
# Macro F1 score: 0.6834281732667518 and Micro F1 Score 0.6914893617021277
# (840, 600) (840,) (94, 600) (94,)
# Macro F1 score: 0.6382978723404255 and Micro F1 Score 0.6382978723404256
# (841, 600) (841,) (93, 600) (93,)
# Macro F1 score: 0.7571225071225072 and Micro F1 Score 0.7634408602150536
# (841, 600) (841,) (93, 600) (93,)
# Macro F1 score: 0.6229584153828334 and Micro F1 Score 0.6236559139784946
# (841, 600) (841,) (93, 600) (93,)
# Macro F1 score: 0.6292213883677298 and Micro F1 Score 0.6344086021505376
# (841, 600) (841,) (93, 600) (93,)
# Macro F1 score: 0.7507309941520468 and Micro F1 Score 0.7634408602150536
# (841, 600) (841,) (93, 600) (93,)
# Macro F1 score: 0.7029456997515675 and Micro F1 Score 0.7096774193548389
# (841, 600) (841,) (93, 600) (93,)
# Macro F1 score: 0.7311827956989247 and Micro F1 Score 0.7311827956989246
# Macro F1 score: 0.7056237794870769 and Micro F1 Score 0.7098146877144819
# Obesity
# (565, 600) (565,) (63, 600) (63,)
# Macro F1 score: 0.6818181818181818 and Micro F1 Score 0.6825396825396826
# (565, 600) (565,) (63, 600) (63,)
# Macro F1 score: 0.6027742749054225 and Micro F1 Score 0.6031746031746031
# (565, 600) (565,) (63, 600) (63,)
# Macro F1 score: 0.6981084489281211 and Micro F1 Score 0.6984126984126984
# (565, 600) (565,) (63, 600) (63,)
# Macro F1 score: 0.6906177306797621 and Micro F1 Score 0.6984126984126984
# (565, 600) (565,) (63, 600) (63,)
# Macro F1 score: 0.6166328600405679 and Micro F1 Score 0.6190476190476191
# (565, 600) (565,) (63, 600) (63,)
# Macro F1 score: 0.7428571428571429 and Micro F1 Score 0.746031746031746
# (565, 600) (565,) (63, 600) (63,)
# Macro F1 score: 0.7928155831014418 and Micro F1 Score 0.7936507936507936
# (565, 600) (565,) (63, 600) (63,)
# Macro F1 score: 0.8094758064516129 and Micro F1 Score 0.8095238095238095
# (566, 600) (566,) (62, 600) (62,)
# Macro F1 score: 0.7574967405475879 and Micro F1 Score 0.7580645161290323
# (566, 600) (566,) (62, 600) (62,)
# Macro F1 score: 0.6447916666666667 and Micro F1 Score 0.6451612903225806
# Macro F1 score: 0.7037388435996507 and Micro F1 Score 0.7054019457245263
# OSA
# (910, 600) (910,) (102, 600) (102,)
# Macro F1 score: 0.8618955512572534 and Micro F1 Score 0.8627450980392157
# (910, 600) (910,) (102, 600) (102,)
# Macro F1 score: 0.832544664413327 and Micro F1 Score 0.8333333333333334
# (911, 600) (911,) (101, 600) (101,)
# Macro F1 score: 0.8369652945924133 and Micro F1 Score 0.8415841584158416
# (911, 600) (911,) (101, 600) (101,)
# Macro F1 score: 0.8833595800524934 and Micro F1 Score 0.8910891089108911
# (911, 600) (911,) (101, 600) (101,)
# Macro F1 score: 0.8810832025117739 and Micro F1 Score 0.8811881188118812
# (911, 600) (911,) (101, 600) (101,)
# Macro F1 score: 0.8907033939990162 and Micro F1 Score 0.8910891089108911
# (911, 600) (911,) (101, 600) (101,)
# Macro F1 score: 0.9205974842767295 and Micro F1 Score 0.9207920792079208
# (911, 600) (911,) (101, 600) (101,)
# Macro F1 score: 0.9164598842018198 and Micro F1 Score 0.9207920792079208
# (911, 600) (911,) (101, 600) (101,)
# Macro F1 score: 0.8710849288168876 and Micro F1 Score 0.8712871287128713
# (911, 600) (911,) (101, 600) (101,)
# Macro F1 score: 0.8440876813831429 and Micro F1 Score 0.8514851485148515
# Macro F1 score: 0.8738781665504858 and Micro F1 Score 0.8765385362065619
# PVD
# (844, 600) (844,) (94, 600) (94,)
# Macro F1 score: 0.7978494623655915 and Micro F1 Score 0.7978723404255319
# (844, 600) (844,) (94, 600) (94,)
# Macro F1 score: 0.8544371649791542 and Micro F1 Score 0.8617021276595744
# (844, 600) (844,) (94, 600) (94,)
# Macro F1 score: 0.8297872340425532 and Micro F1 Score 0.8297872340425532
# (844, 600) (844,) (94, 600) (94,)
# Macro F1 score: 0.864942528735632 and Micro F1 Score 0.8723404255319149
# (844, 600) (844,) (94, 600) (94,)
# Macro F1 score: 0.861561119293078 and Micro F1 Score 0.8617021276595744
# (844, 600) (844,) (94, 600) (94,)
# Macro F1 score: 0.9001769911504425 and Micro F1 Score 0.9042553191489362
# (844, 600) (844,) (94, 600) (94,)
# Macro F1 score: 0.7976662512744987 and Micro F1 Score 0.7978723404255319
# (844, 600) (844,) (94, 600) (94,)
# Macro F1 score: 0.825925925925926 and Micro F1 Score 0.8297872340425532
# (845, 600) (845,) (93, 600) (93,)
# Macro F1 score: 0.8493055555555555 and Micro F1 Score 0.8494623655913978
# (845, 600) (845,) (93, 600) (93,)
# Macro F1 score: 0.8454415954415955 and Micro F1 Score 0.8494623655913978
# Macro F1 score: 0.8427093828764025 and Micro F1 Score 0.8454243880118966
# Venous_Insufficiency
# (867, 600) (867,) (97, 600) (97,)
# Macro F1 score: 0.822859598238264 and Micro F1 Score 0.8247422680412371
# (867, 600) (867,) (97, 600) (97,)
# Macro F1 score: 0.8761702127659574 and Micro F1 Score 0.8762886597938144
# (867, 600) (867,) (97, 600) (97,)
# Macro F1 score: 0.8746770025839794 and Micro F1 Score 0.8762886597938144
# (867, 600) (867,) (97, 600) (97,)
# Macro F1 score: 0.8184920198128783 and Micro F1 Score 0.8247422680412371
# (868, 600) (868,) (96, 600) (96,)
# Macro F1 score: 0.8590626764539808 and Micro F1 Score 0.8645833333333333
# (868, 600) (868,) (96, 600) (96,)
# Macro F1 score: 0.8642149929278642 and Micro F1 Score 0.8645833333333333
# (868, 600) (868,) (96, 600) (96,)
# Macro F1 score: 0.874945722970039 and Micro F1 Score 0.875
# (868, 600) (868,) (96, 600) (96,)
# Macro F1 score: 0.8306878306878307 and Micro F1 Score 0.8333333333333334
# (868, 600) (868,) (96, 600) (96,)
# Macro F1 score: 0.8644509612251547 and Micro F1 Score 0.8645833333333333
# (868, 600) (868,) (96, 600) (96,)
# Macro F1 score: 0.905994995103906 and Micro F1 Score 0.90625
# Macro F1 score: 0.8591556012769855 and Micro F1 Score 0.8610395189003437

# %%
with open("./results/tf-idf/performance_SVM_InfoGain.csv", "w", newline="") as file:
    writer = csv.writer(file)

    # write the RF heading and the subheadings for Micro F1 and Macro F1
    writer.writerow(column_headings)
    
all_f1_macro_scores = []
all_f1_micro_scores = []

for morbidity in morbidities:
    train_preprocessed_df = pd.read_csv('./dataset/train/train_intuitive_preprocessed.csv')
    train_preprocessed_df = train_preprocessed_df[train_preprocessed_df[morbidity].isin([1.0, 0.0])]

    X, Y, words = FeatureGeneration(train_preprocessed_df, morbidity).tf_idf()
    if len(collections.Counter(list(Y)).keys()) < 2:
        f1_macro = 1
        f1_micro = 1
    else:
        print(morbidity)
        smote = SMOTE(random_state=42,k_neighbors=2)
        X_train_resampled, y_train_resampled = smote.fit_resample(X, Y)
        X, Y =  X_train_resampled, y_train_resampled
        
        # add KFold cross validation
        skf = KFold(n_splits=10, shuffle=True, random_state=42)

        f1_macro_list = []
        f1_micro_list = []
        for train_idx, val_idx in skf.split(X, Y):
            X_train_fold, Y_train_fold = X[train_idx], Y[train_idx]
            X_val_fold, Y_val_fold = X[val_idx], Y[val_idx]

            # Training RF using TF-IDF Representation
            svm_obj = SVM(X_train_fold, Y_train_fold, X_val_fold, Y_val_fold, 100)
            svm_obj.feature_selection_InfoGainAttributeEval(morbidity)
            svm_obj.train()

            f1_macro, f1_micro = svm_obj.test_and_evaluate()

            f1_macro_list.append(f1_macro)
            f1_micro_list.append(f1_micro)

        f1_macro = np.mean(f1_macro_list)
        f1_micro = np.mean(f1_micro_list)
    print(f"Macro F1 score: {f1_macro} and Micro F1 Score {f1_micro}")
    all_f1_macro_scores.append(f1_macro)
    all_f1_micro_scores.append(f1_micro)

    row_heading = morbidity

    # data to be written to the CSV file
    data = [f1_macro, f1_micro]

    with open("./results/tf-idf/performance_SVM_InfoGain.csv", "a", newline="") as file:
        writer = csv.writer(file)
        row = [row_heading]
        row.extend(data)
        writer.writerow(row)

with open("./results/tf-idf/performance_SVM_InfoGain.csv", "a", newline="") as file:
    writer = csv.writer(file)
    row = ["Overall-Average"]
    row.extend([sum(all_f1_macro_scores)/len(all_f1_macro_scores),  sum(all_f1_micro_scores)/len(all_f1_micro_scores) ])
    writer.writerow(row)
# Out:
# Asthma
# (903, 600) (903,) (101, 600) (101,)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 35
#      33 # Training RF using TF-IDF Representation
#      34 svm_obj = SVM(X_train_fold, Y_train_fold, X_val_fold, Y_val_fold, 100)
# ---> 35 svm_obj.feature_selection_InfoGainAttributeEval(morbidity)
#      36 svm_obj.train()
#      38 f1_macro, f1_micro = svm_obj.test_and_evaluate()
#
# Cell In[3], line 26, in SVM.feature_selection_InfoGainAttributeEval(self, morbidity)
#      25 def feature_selection_InfoGainAttributeEval(self, morbidity):
# ---> 26     loader = Loader(classname="weka.core.converters.ArffLoader")
#      27     train_data = loader.load_file(f"./dataset/train/train_{morbidity}_tfidf.arff")
#      28     train_data.class_is_last()
#
# File ~/Documents/Classes/CS598DLH/.conda/lib/python3.10/site-packages/weka/core/converters.py:42, in Loader.__init__(self, classname, jobject, options)
#      31 """
#      32 Initializes the specified loader either using the classname or the JB_Object.
#      33
#    (...)
#      39 :type options: list
#      40 """
#      41 if jobject is None:
# ---> 42     jobject = Loader.new_instance(classname)
#      43 self.enforce_type(jobject, "weka.core.converters.Loader")
#      44 super(Loader, self).__init__(jobject=jobject, options=options)
#
# File ~/Documents/Classes/CS598DLH/.conda/lib/python3.10/site-packages/weka/core/classes.py:614, in JavaObject.new_instance(cls, classname, options)
#     609     if options is None:
#     610         options = []
#     611     return javabridge.static_call(
#     612         "Lweka/core/Utils;", "forName",
#     613         "(Ljava/lang/Class;Ljava/lang/String;[Ljava/lang/String;)Ljava/lang/Object;",
# --> 614         javabridge.class_for_name("java.lang.Object"), classname, options)
#     615 except JavaException as e:
#     616     print("Failed to instantiate " + classname + ": " + str(e))
#
# File ~/Documents/Classes/CS598DLH/.conda/lib/python3.10/site-packages/javabridge/jutil.py:1743, in class_for_name(classname, ldr)
#    1737 '''Return a ``java.lang.Class`` for the given name.
#    1738
#    1739 :param classname: the class name in dotted form, e.g. "java.lang.String"
#    1740
#    1741 '''
#    1742 if ldr == "system":
# -> 1743     ldr = static_call('java/lang/ClassLoader', 'getSystemClassLoader',
#    1744                       '()Ljava/lang/ClassLoader;')
#    1745 return static_call('java/lang/Class', 'forName',
#    1746                    '(Ljava/lang/String;ZLjava/lang/ClassLoader;)'
#    1747                    'Ljava/lang/Class;',
#    1748                    classname, True, ldr)
#
# File ~/Documents/Classes/CS598DLH/.conda/lib/python3.10/site-packages/javabridge/jutil.py:939, in static_call(class_name, method_name, sig, *args)
#     928 '''Call a static method on a class
#     929
#     930 :param class_name: name of the class, using slashes
#    (...)
#     936
#     937 '''
#     938 env = get_env()
# --> 939 fn = make_static_call(class_name, method_name, sig)
#     940 args_sig = split_sig(sig[1:sig.find(')')])
#     941 ret_sig = sig[sig.find(')')+1:]
#
# File ~/Documents/Classes/CS598DLH/.conda/lib/python3.10/site-packages/javabridge/jutil.py:910, in make_static_call(class_name, method_name, sig)
#     899 '''Create a function that performs a call of a static method
#     900
#     901 make_static_call produces a function that is faster than static_call
#    (...)
#     907
#     908 '''
#     909 env = get_env()
# --> 910 klass = env.find_class(class_name)
#     911 if klass is None:
#     912     jexception = get_env().exception_occurred()
#
# AttributeError: 'NoneType' object has no attribute 'find_class'
